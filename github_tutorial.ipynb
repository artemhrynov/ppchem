# %% [markdown]
# ## Bash commands
# cd .. #move one directory up
#
# ## Git commands
#
# '''bash
# git switch <name of the branch> #switches branches
# git switch -c <new_bracnh_name> #create a new branch and swithc there
# git branch -d <branch_name> #delete a local branch
# git branch #show local branches
# git status #see modifications, etc
# git add <file> #stage one file
# git add . #stage all changed files
# git commit -m "Your message" #create a commit with a message
# git push #pushes your current branch committed changes to GitHub
# git pull #dowmload and merge changes from GitHub
# git fetch #download changes without merging them
